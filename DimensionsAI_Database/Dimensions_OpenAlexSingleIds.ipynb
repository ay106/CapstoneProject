# %% [markdown]
# ### Looking at the Overlap between single id's in Dimensions and OpenAlex

# %%
import csv
import pandas as pd
import numpy as np
import json 
import requests
from nameparser import HumanName

# %%
with open("nameOneIDs.csv", encoding="latin-1") as fileToRead:
    csvReader = csv.DictReader(fileToRead)   # create reader object
    rows = [row for row in csvReader]        # do the reading of each row

print(len(rows))
df = pd.DataFrame(data=rows)
names = df['Name']
#print(names)
# Out:
# 993

# %%
# Initialize a dictionary to store the queried IDs for each physician-scientist
ids_dictionary = {}

# Initialize a set to store the failed queries
failed_queries = set()
count = 0

for person in names:
    cursor = "*"
    author_name = person.lower()
    # Keep making queries until the request is successful or the maximum number of queries is reached
    while True:
        query_author = f'https://api.openalex.org/authors?search={author_name}&per_page=100&cursor={cursor}'
        
        try:
            # Make the API request
            response = requests.get(query_author)


            # Check if the request was successful
            if response.status_code == 200:
                # Get the list of inventors from the response
                authors = response.json()["results"]

                # Iterate over the author and add them to the dictionary
                for author in authors:
                    name = HumanName(author.pop("display_name"))
    
                    # remove unnecessary features
                    author.pop("display_name_alternatives")
                    author.pop("orcid")
                    author.pop("summary_stats")
                    author.pop("x_concepts")
                    author.pop("works_api_url")
                    
                    author["id"] = author["id"][21:]
                    author["name_first"] = name.first if len(name.first) > 1 else None
                    author["name_middle"] = name.middle if len(name.middle) > 1 else None
                    author["name_last"] = name.last if len(name.last) > 1 else None
                    author["works"] = []
                    
                    author["api"] = "openAlex"
                    
                    if author_name not in ids_dictionary:
                        ids_dictionary[author_name] = {}
                    
                    if author["id"] not in ids_dictionary[author_name]:
                        ids_dictionary[author_name][author["id"]] = {}

                    ids_dictionary[author_name][author["id"]] = author

            # Break out of the loop if there are no more authors
            if not authors:
                break

            # Update the query parameters with the next `cursor` value
            cursor = response.json()["meta"]["next_cursor"]
                
        # If the request is unsuccessful, add the query name and `after` value to the failed queries set
        except Exception as e:
            print(e)
            failed_queries.add((author_name, cursor))
            break
    count +=1
    print(f'{count}. {author_name} + done')

# Print the failed queries
print(f"Failed queries: {failed_queries}")
# Out:
# 1. yale nemerson + done
# 2. elia ayoub + done
# 3. john dietschy + done
# 4. yale enson + done
# 5. mehran goulian + done
# 6. norman javitt + done
# 7. hermes kontos + done
# 8. gilbert levinson + done
# 9. harvey marver + done
# 10. harold neu + done
# 11. arthur eisen + done
# 12. barry fanburg + done
# 13. dorothea zucker-franklin + done
# 14. nathan zvaifler + done
# 15. phyllis bodel + done
# 16. sidney cooperband + done
# 17. jacques kessler + done
# 18. stanley korenman + done
# 19. gildon beall + done
# 20. neil cherniack + done
# 21. blas frangione + done
# 22. irwin freedberg + done
# 23. thomas merimee + done
# 24. i samloff + done
# 25. wadi suki + done
# 26. shirley ebbe + done
# 27. clyde bardin + done
# 28. ward bullock + done
# 29. jack coburn + done
# 30. richard levere + done
# 31. michael mosesson + done
# 32. ursula muller-eberhard + done
# 33. leon sabath + done
# 34. burton sobel + done
# 35. martin surks + done
# 36. siamak adibi + done
# 37. carl bentzel + done
# 38. kevin catt + done
# 39. wallace clyde + done
# 40. harvey colten + done
# 41. bernard forget + done
# 42. eugene frenkel + done
# 43. jared grantham + done
# 44. mitchell halperin + done
# 45. leon hoyer + done
# 46. jamshid javid + done
# 47. marshall lichtman + done
# 48. ruy lourenco + done
# 49. john salvaggio + done
# 50. manning thaler + done
# 51. harry beaty + done
# 52. viktor bokisch + done
# 53. inder chopra + done
# 54. darrell fanestil + done
# 55. alexander fefer + done
# 56. darryl granner + done
# 57. ronald kalkhoff + done
# 58. sanford krantz + done
# 59. sheldon rothenberg + done
# 60. john voorhees + done
# 61. joseph warshaw + done
# 62. aubie angel + done
# 63. edgar cathcart + done
# 64. mortimer civan + done
# 65. coy fitch + done
# 66. franklyn knox + done
# 67. julian niemetz + done
# 68. jeremiah silbert + done
# 69. antero so + done
# 70. frank stockdale + done
# 71. leonard jarett + done
# 72. edwin beachey + done
# 73. stanley birge + done
# 74. guenther boden + done
# 75. donald castell + done
# 76. willard daggett + done
# 77. vincent discala + done
# 78. aron fisher + done
# 79. harvey gralnick + done
# 80. khursheed jeejeebhoy + done
# 81. george kaloyanides + done
# 82. laurence kedes + done
# 83. robert orange + done
# 84. hugo jasin + done
# 85. robert adelstein + done
# 86. joseph avruch + done
# 87. roland blantz + done
# 88. john brunzell + done
# 89. frederick derubertis + done
# 90. kenneth gabbay + done
# 91. jack hawiger + done
# 92. micheline mathews-roth + done
# 93. ward olsen + done
# 94. ruy soeiro + done
# 95. bobby stinebaugh + done
# 96. andre van herle + done
# 97. kirk wuepper + done
# 98. ashley haase + done
# 99. philip askenase + done
# 100. philip coffino + done
# 101. raphael dolin + done
# 102. dwain eckberg + done
# 103. glenn peake + done
# 104. daniel roncari + done
# 105. irwin scher + done
# 106. isaias spilberg + done
# 107. gordon weir + done
# 108. otto goetze + done
# 109. nicholas kredich + done
# 110. chang-seng liang + done
# 111. makio ogawa + done
# 112. sheldon pinnell + done
# 113. matthew rechler + done
# 114. david rosenstreich + done
# 115. shigeru sassa + done
# 116. babette weksler + done
# 117. thalia papayannopoulou + done
# 118. david bilheimer + done
# 119. neil blacklow + done
# 120. mark entman + done
# 121. philip guzelian + done
# 122. david kleinberg + done
# 123. ione kourides + done
# 124. rob macgregor + done
# 125. charles mansbach + done
# 126. harry margolius + done
# 127. philip schein + done
# 128. richard shadduck + done
# 129. william yarger + done
# 130. jouni uitto + done
# 131. blanche alter + done
# 132. merrill benson + done
# 133. herbert bonkovsky + done
# 134. raymond burk + done
# 135. edward crandall + done
# 136. bertram felsher + done
# 137. marvin gershengorn + done
# 138. sherman levine + done
# 139. willis maddrey + done
# 140. howard nankin + done
# 141. thomas provost + done
# 142. detlef schlondorff + done
# 143. manjeri venkatachalam + done
# 144. roger winkle + done
# 145. jr. benz + done
# 146. tomas berl + done
# 147. steven burakoff + done
# 148. leon fine + done
# 149. ralph giannella + done
# 150. nortin hadler + done
# 151. keith hruska + done
# 152. j. kolhouse + done
# 153. douglas lowy + done
# 154. aubrey morrison + done
# 155. carl pepine + done
# 156. arnold postlethwaite + done
# 157. alex rabinovitch + done
# 158. elliot rayfield + done
# 159. arleen rifkind + done
# 160. morris schambelan + done
# 161. eugene straus + done
# 162. bevra hahn + done
# 163. carl nathan + done
# 164. zalman agus + done
# 165. carl apstein + done
# 166. jay berzofsky + done
# 167. barton haynes + done
# 168. carl leier + done
# 169. meyer lifschitz + done
# 170. james niedel + done
# 171. john repine + done
# 172. anton schoolwerth + done
# 173. sanford shattil + done
# 174. f. toback + done
# 175. george wilner + done
# 176. allan wolkoff + done
# 177. stephen zinner + done
# 178. thomas lawley + done
# 179. itamar abrass + done
# 180. robert bast jr. + done
# 181. barry festoff + done
# 182. fred finkelman + done
# 183. curt freed + done
# 184. harvey golomb + done
# 185. charles homcy + done
# 186. mae hultin + done
# 187. vanda lennon + done
# 188. thurman mckinney + done
# 189. bruce nisula + done
# 190. ivor royston + done
# 191. glen van loon + done
# 192. ronald whisler + done
# 193. reed wickner + done
# 194. iekuni ichikawa + done
# 195. douglas cines + done
# 196. martin cogan + done
# 197. theodore gabig + done
# 198. louis lange + done
# 199. mercio perrin + done
# 200. zaverio ruggeri + done
# 201. allen steere + done
# 202. william stenson + done
# 203. jimmie sylvester + done
# 204. robert yolken + done
# 205. ernesto canalis + done
# 206. clifton bogardus + done
# 207. kiertisin dharmsathaphorn + done
# 208. boris draznin + done
# 209. leslie hillis + done
# 210. marguerite kay + done
# 211. stanley korsmeyer + done
# 212. anne nicholson-weller + done
# 213. jerry radziuk + done
# 214. edward shortliffe + done
# 215. jess thoene + done
# 216. allan pack + done
# 217. bennett blitzer + done
# 218. gerry boss + done
# 219. gary brittenham + done
# 220. dan granoff + done
# 221. henry hulter + done
# 222. vishwanath lingappa + done
# 223. virginia savin + done
# 224. arthur slutsky + done
# 225. frederick southwick + done
# 226. joseph verbalis + done
# 227. samuel santoro + done
# 228. greti aguilera + done
# 229. celso gomez-sanchez + done
# 230. mark knepper + done
# 231. roger perlmutter + done
# 232. salvatore pizzo + done
# 233. kenneth polonsky + done
# 234. paul sondel + done
# 235. howard welgus + done
# 236. mark zern + done
# 237. lee nadler + done
# 238. christine abrass + done
# 239. david benditt + done
# 240. loran clement + done
# 241. andre de troyer + done
# 242. douglas faller + done
# 243. james gadek + done
# 244. jeffrey kudlow + done
# 245. henry masur + done
# 246. phillip pizzo + done
# 247. edward prochownik + done
# 248. william scheld + done
# 249. james shelhamer + done
# 250. manikkam suthanthiran + done
# 251. william tamborlane + done
# 252. owen witte + done
# 253. wishwa kapoor + done
# 254. jonathan ashwell + done
# 255. bruce beutler + done
# 256. david bushinsky + done
# 257. mario chojkier + done
# 258. charles czeisler + done
# 259. clark distelhorst + done
# 260. subhash kukreja + done
# 261. joseph majzoub + done
# 262. cary mariash + done
# 263. robert meenan + done
# 264. reed pyeritz + done
# 265. alvin schmaier + done
# 266. ii thomas + done
# 267. eric topol + done
# 268. robert califf + done
# 269. lawrence samelson + done
# 270. carmen allegra + done
# 271. akhil bidani + done
# 272. gordon ginder + done
# 273. michael goligorsky + done
# 274. yusuf hannun + done
# 275. anne klibanski + done
# 276. richard kolesnick + done
# 277. theodore krontiris + done
# 278. jeffrey leiden + done
# 279. john lollar + done
# 280. york miller + done
# 281. chikao morimoto + done
# 282. mortimer poncz + done
# 283. lanny rosenwasser + done
# 284. julian solway + done
# 285. joel taurog + done
# 286. petros tsipouras + done
# 287. carl-wilhelm vogel + done
# 288. janis abkowitz + done
# 289. marilyn telen + done
# 290. andres blei + done
# 291. allan detsky + done
# 292. francisco gonzalez-scarano + done
# 293. frederick gorelick + done
# 294. carl june + done
# 295. dennis klinman + done
# 296. neil reiner + done
# 297. victor schuster + done
# 298. harry shamoon + done
# 299. elizabeth nabel + done
# 300. william nauseef + done
# 301. perumal thiagarajan + done
# 302. mark zeidel + done
# 303. bradley britigan + done
# 304. george caughey + done
# 305. israel charo + done
# 306. arthur gutierrez-hartmann + done
# 307. v. holers + done
# 308. john kehrl + done
# 309. daniel rotrosen + done
# 310. steven shoelson + done
# 311. gregory vercellotti + done
# 312. katherine hajjar + done
# 313. jeff sands + done
# 314. elliot androphy + done
# 315. barbara ballermann + done
# 316. luiz belardinelli + done
# 317. peter bitterman + done
# 318. karol bomsztyk + done
# 319. john cowdery + done
# 320. jörg goronzy + done
# 321. richard granstein + done
# 322. lisa iezzoni + done
# 323. seigo izumo + done
# 324. donald kohan + done
# 325. alan krensky + done
# 326. elias lianos + done
# 327. charles natanson + done
# 328. michael selsted + done
# 329. james shayman + done
# 330. steven spitalnik + done
# 331. mary sunday + done
# 332. larry tobacman + done
# 333. dale umetsu + done
# 334. cornelia weyand + done
# 335. jay zweier + done
# 336. karl nath + done
# 337. bishr omary + done
# 338. fuad ziyadeh + done
# 339. peter arvan + done
# 340. webster cavenee + done
# 341. fabio cominelli + done
# 342. mary dinauer + done
# 343. samuel hawgood + done
# 344. brian kobilka + done
# 345. howard lippton + done
# 346. sanford markowitz + done
# 347. thomas pallone + done
# 348. william petri jr. + done
# 349. peter st. george-hyslop + done
# 350. jonathan stamler + done
# 351. laurence turka + done
# 352. stephen wank + done
# 353. fredric wondisford + done
# 354. troyen brennan + done
# 355. richard bucala + done
# 356. phillip chance + done
# 357. john dipersio + done
# 358. lee helman + done
# 359. harald jüppner + done
# 360. thomas kleyman + done
# 361. gary koretzky + done
# 362. joan kreiss + done
# 363. laurence mcmahon + done
# 364. westley reeves + done
# 365. barrett rollins + done
# 366. robert star + done
# 367. cy stein + done
# 368. mary tinetti + done
# 369. peter igarashi + done
# 370. sally radovick + done
# 371. virginia broudy + done
# 372. sherin devaskar + done
# 373. robert doms + done
# 374. pascal goldschmidt-clermont + done
# 375. douglas golenbock + done
# 376. razelle kurzrock + done
# 377. stephen meltzer + done
# 378. mark musen + done
# 379. stephen nimer + done
# 380. dwain thiele + done
# 381. hagop youssoufian + done
# 382. ferric fang + done
# 383. donald landry + done
# 384. michael parmacek + done
# 385. wadie bahou + done
# 386. roberto civitelli + done
# 387. terence dermody + done
# 388. erol fikrig + done
# 389. alfred george jr. + done
# 390. richard kitsis + done
# 391. alan kopin + done
# 392. juanita merchant + done
# 393. ori rotstein + done
# 394. mark schlissel + done
# 395. robert seder + done
# 396. stefan somlo + done
# 397. howard worman + done
# 398. wafik el-deiry + done
# 399. robert farese jr. + done
# 400. andrew karaplis + done
# 401. richard koup + done
# 402. donna mancini + done
# 403. paul mccray jr. + done
# 404. michel nussenzweig + done
# 405. marc reitman + done
# 406. marschall runge + done
# 407. clay semenkovich + done
# 408. philip shaul + done
# 409. virend somers + done
# 410. raymond warrell + done
# 411. george yancopoulos + done
# 412. jonathan barasch + done
# 413. david virshup + done
# 414. mone zaidi + done
# 415. mario capecchi + done
# 416. timothy cover + done
# 417. linda demer + done
# 418. iswar hariharan + done
# 419. kirk knowlton + done
# 420. larry moreland + done
# 421. william skach + done
# 422. francis spinale + done
# 423. jerry vockley + done
# 424. per westermark + done
# 425. jeffrey balser + done
# 426. lionel ivashkiv + done
# 427. david nanus + done
# 428. allan brasier + done
# 429. ethel cesarman + done
# 430. augustine choi + done
# 431. michael donnenberg + done
# 432. serpil erzurum + done
# 433. glenn fishman + done
# 434. david harlan + done
# 435. stella kourembanas + done
# 436. jonathan kurie + done
# 437. jonathan licht + done
# 438. macrae linton + done
# 439. keith mccrae + done
# 440. orson moe + done
# 441. lloyd cantley + done
# 442. fadi lakkis + done
# 443. william bishai + done
# 444. peter carmeliet + done
# 445. lewis chodosh + done
# 446. marie demay + done
# 447. jennifer grandis + done
# 448. charles lowenstein + done
# 449. anne moscona + done
# 450. warren pear + done
# 451. david pellman + done
# 452. anthony wynshaw-boris + done
# 453. john wysolmerski + done
# 454. christopher karp + done
# 455. wadih arap + done
# 456. serdar bulun + done
# 457. bruce conklin + done
# 458. kenneth freedberg + done
# 459. joseph heitman + done
# 460. larry kwak + done
# 461. louis luttrell + done
# 462. louis muglia + done
# 463. peter mundel + done
# 464. ellis neufeld + done
# 465. douglas nixon + done
# 466. ariel pablos-mendez + done
# 467. richard quigg + done
# 468. theodore standiford + done
# 469. luc teyton + done
# 470. andrew blauvelt + done
# 471. fabio candotti + done
# 472. preet chaudhary + done
# 473. maripat corr + done
# 474. phyllis dennery + done
# 475. mary disis + done
# 476. glenn dranoff + done
# 477. samir el-dahr + done
# 478. paul frenette + done
# 479. i-cheng ho + done
# 480. clay marsh + done
# 481. jorge plutzky + done
# 482. theodora ross + done
# 483. barry sleckman + done
# 484. dwight towler + done
# 485. flordeliza villanueva + done
# 486. rexford ahima + done
# 487. crystal mackall + done
# 488. carol mangione + done
# 489. rhoda alani + done
# 490. josé baselga + done
# 491. tamara doering + done
# 492. daniel eitzman + done
# 493. elizabeth henske + done
# 494. alp ikizler + done
# 495. hans-peter kiem + done
# 496. sharon moe + done
# 497. kelle moley + done
# 498. alessandra pernis + done
# 499. kenneth pienta + done
# 500. ernestina schipani + done
# 501. ramesh shivdasani + done
# 502. andrea todisco + done
# 503. pier pandolfi + done
# 504. susan quaggin + done
# 505. joseph zabner + done
# 506. george gittes + done
# 507. julie saba + done
# 508. shanthi sitaraman + done
# 509. john spertus + done
# 510. kai wucherpfennig + done
# 511. jayakrishna ambati + done
# 512. george cotsarelis + done
# 513. kenneth covinsky + done
# 514. david engman + done
# 515. john frangioni + done
# 516. tejvir khurana + done
# 517. fadlo khuri + done
# 518. christos mantzoros + done
# 519. scott plevy + done
# 520. chaim putterman + done
# 521. doris stoffers + done
# 522. marcus altfeld + done
# 523. frank anania + done
# 524. gerard blobe + done
# 525. ivan fuss + done
# 526. sanjiv gambhir + done
# 527. steve georas + done
# 528. michael girardi + done
# 529. todd golub + done
# 530. robert heuckeroth + done
# 531. pasi janne + done
# 532. igor koralnik + done
# 533. barry paw + done
# 534. warren shlomchik + done
# 535. chloe thio + done
# 536. kevin volpp + done
# 537. dan barouch + done
# 538. david hackam + done
# 539. rulan parekh + done
# 540. murat arcasoy + done
# 541. valder arruda + done
# 542. phillip febbo + done
# 543. tina hartert + done
# 544. jeanmarie houghton + done
# 545. samir khleif + done
# 546. keith march + done
# 547. ari melnick + done
# 548. vamsi mootha + done
# 549. mary patti + done
# 550. stephanie seminara + done
# 551. john stamatoyannopoulos + done
# 552. sapna syngal + done
# 553. michael tomasson + done
# 554. hensin tsao + done
# 555. omaida velazquez + done
# 556. feroz papa + done
# 557. loren walensky + done
# 558. ernesto bernal-mizrachi + done
# 559. catherine bollard + done
# 560. russ carstens + done
# 561. juan celedón + done
# 562. charleen chu + done
# 563. jonathan dranoff + done
# 564. charles esmon + done
# 565. nikolaos frangogiannis + done
# 566. maura gillison + done
# 567. paul goepfert + done
# 568. laura haneline + done
# 569. tzung hsiai + done
# 570. terrie inder + done
# 571. bjorn knollmann + done
# 572. gary luker + done
# 573. mehrdad matloubian + done
# 574. franck mauvais-jarvis + done
# 575. raghavendra mirmira + done
# 576. lucila ohno-machado + done
# 577. jordan orange + done
# 578. muredach reilly + done
# 579. constantine stratakis + done
# 580. andrew alspaugh + done
# 581. kenneth ataga + done
# 582. james bradner + done
# 583. jen-tsan chi + done
# 584. kojo elenitoba-johnson + done
# 585. evanthia galanis + done
# 586. terrence geiger + done
# 587. michael kapiloff + done
# 588. nancy keating + done
# 589. darrell kotton + done
# 590. christopher landrigan + done
# 591. theresa lu + done
# 592. william matsui + done
# 593. flora sam + done
# 594. anath shalev + done
# 595. david solit + done
# 596. katalin susztak + done
# 597. eric sweet-cordero + done
# 598. joshua thurman + done
# 599. xander wehrens + done
# 600. john wemmie + done
# 601. michelle winn + done
# 602. james zimring + done
# 603. rochelle walensky + done
# 604. brian zuckerbraun + done
# 605. joel blankson + done
# 606. jorge di paola + done
# 607. adolfo ferrando + done
# 608. keith flaherty + done
# 609. jaime grutzendler + done
# 610. chyi-song hsieh + done
# 611. ola landgren + done
# 612. jonathan maltzman + done
# 613. kieren mather + done
# 614. hidayatullah munshi + done
# 615. nuria pastor-soler + done
# 616. amanda paulovich + done
# 617. irina petrache + done
# 618. marc sabatine + done
# 619. dorry segev + done
# 620. michael shlipak + done
# 621. fayyaz sutterwala + done
# 622. lorraine ware + done
# 623. scott floyd + done
# 624. benjamin gewurz + done
# 625. anne cappola + done
# 626. iris jaffe + done
# 627. vibha lama + done
# 628. sana al-khatib + done
# 629. john amory + done
# 630. mary armanios + done
# 631. carlos bernal-mizrachi + done
# 632. ebony boulware + done
# 633. laura calvi + done
# 634. andrew einstein + done
# 635. john fingert + done
# 636. kelly gebo + done
# 637. wolfram goessling + done
# 638. noyan gokce + done
# 639. sherita golden + done
# 640. priscilla hsue + done
# 641. farouc jaffer + done
# 642. steven kawut + done
# 643. bryan kestenbaum + done
# 644. ivan maillard + done
# 645. borna mehrad + done
# 646. yaël mossé + done
# 647. matthias nahrendorf + done
# 648. puneet opal + done
# 649. jean-charles soria + done
# 650. elizabeth speliotes + done
# 651. hans-guido wendel + done
# 652. motoko yanagita + done
# 653. gaorav gupta + done
# 654. alex kentsis + done
# 655. jeniel nett + done
# 656. clara abraham + done
# 657. rajendra apte + done
# 658. hulya bayir + done
# 659. alison bertuch + done
# 660. jonathan bogan + done
# 661. g.r. budinger + done
# 662. raphaela goldbach-mansky + done
# 663. eric haura + done
# 664. gurjit hershey + done
# 665. ken inoki + done
# 666. catherine keegan + done
# 667. celina kleer + done
# 668. kenneth langa + done
# 669. frederick masoudi + done
# 670. linda mcallister-lucas + done
# 671. leonid metelitsa + done
# 672. ivan moskowitz + done
# 673. paul nghiem + done
# 674. mark nicolls + done
# 675. shuji ogino + done
# 676. sophie paczesny + done
# 677. akhilesh reddy + done
# 678. amr sawalha + done
# 679. hans-willem snoeck + done
# 680. lorenz studer + done
# 681. viviane tabar + done
# 682. jens titze + done
# 683. natalie török + done
# 684. sing way + done
# 685. jedd wolchok + done
# 686. theresa alenghat + done
# 687. christina barkauskas + done
# 688. ethan goldberg + done
# 689. jeffery klco + done
# 690. anita mcelroy + done
# 691. sudarshan rajagopal + done
# 692. christine iacobuzio-donahue + done
# 693. sohail tavazoie + done
# 694. jennifer temel + done
# 695. muneesh tewari + done
# 696. manish aghi + done
# 697. ravi amaravadi + done
# 698. jennifer anolik + done
# 699. elliott bennett-guerrero + done
# 700. thomas benzing + done
# 701. renier brentjens + done
# 702. michael fessler + done
# 703. joachim ix + done
# 704. alec kimmelman + done
# 705. atsushi kumanogoh + done
# 706. mathias lichterfeld + done
# 707. steven lipkin + done
# 708. thorsten mempel + done
# 709. jános peti-peterdi + done
# 710. ekihiro seki + done
# 711. william steinbach + done
# 712. lynda stuart + done
# 713. wolfgang winkelmayer + done
# 714. jennifer alexander-brett + done
# 715. shadmehr demehri + done
# 716. charles gawad + done
# 717. kory lavine + done
# 718. bluma lesch + done
# 719. anna molofsky + done
# 720. sahar nissim + done
# 721. vahid afshar-kharghan + done
# 722. balamurali ambati + done
# 723. joseph arron + done
# 724. kamran atabai + done
# 725. jasmohan bajaj + done
# 726. trever bivona + done
# 727. catherine blish + done
# 728. keith choate + done
# 729. wonder drake + done
# 730. elia duh + done
# 731. todd fehniger + done
# 732. hitinder gurm + done
# 733. melina kibbe + done
# 734. pamela ling + done
# 735. funda meric-bernstam + done
# 736. andy minn + done
# 737. sallie permar + done
# 738. carla pugh + done
# 739. ivan rosas + done
# 740. lecia sequist + done
# 741. agata smogorzewska + done
# 742. rebecca sudore + done
# 743. david tuveson + done
# 744. koji yasutomo + done
# 745. heidi cook-andersen + done
# 746. mariella filbin + done
# 747. andrew intlekofer + done
# 748. devanand manoli + done
# 749. seth rakoff-nahoum + done
# 750. dhakshin ramanathan + done
# 751. tiffany scharschmidt + done
# 752. aida habtezion + done
# 753. reshma jagsi + done
# 754. ravindra majeti + done
# 755. sarki abdulkadir + done
# 756. ash alizadeh + done
# 757. nicole calakos + done
# 758. sarat chandarlapaty + done
# 759. aaron cypess + done
# 760. justin dimick + done
# 761. ariel feldstein + done
# 762. martin fernandez-zapico + done
# 763. alessia fornoni + done
# 764. anna greka + done
# 765. erica herzog + done
# 766. beth kirkpatrick + done
# 767. shyamasundaran kottilil + done
# 768. mondira kundu + done
# 769. jonathan kurtis + done
# 770. lona mody + done
# 771. thangamani muthukumar + done
# 772. ivona pandrea + done
# 773. vijay bhoj + done
# 774. aaron carlin + done
# 775. whitney harrington + done
# 776. tamia harris-tryon + done
# 777. kara maxwell + done
# 778. kent mouw + done
# 779. tamer sallam + done
# 780. craig wilen + done
# 781. michael agus + done
# 782. jodie babitt + done
# 783. murat bastepe + done
# 784. sudha biddinger + done
# 785. paul bollyky + done
# 786. jeremy dittman + done
# 787. alexandre dombrovski + done
# 788. matthew freiberg + done
# 789. cary gross + done
# 790. saptarsi haldar + done
# 791. megan haymart + done
# 792. maureen horton + done
# 793. leora horwitz + done
# 794. yujin hoshida + done
# 795. arti hurria + done
# 796. rahul kohli + done
# 797. suneil koliwad + done
# 798. margot kushel + done
# 799. nehal mehta + done
# 800. ann mullally + done
# 801. eirini papapetrou + done
# 802. simone sanna-cherchi + done
# 803. brad spellberg + done
# 804. charlotte sumner + done
# 805. david teachey + done
# 806. mintu turakhia + done
# 807. kareem zaghloul + done
# 808. samuel bakhoum + done
# 809. elizabeth bhoj + done
# 810. keira cohen + done
# 811. benjamin izar + done
# 812. corrine kliment + done
# 813. mark sellmyer + done
# 814. tanya sippy + done
# 815. joshi alumkal + done
# 816. eran bendavid + done
# 817. bibiana bielekova + done
# 818. barry borlaug + done
# 819. marina caskey + done
# 820. kafui dzirasa + done
# 821. souheil el-chemaly + done
# 822. peter groeneveld + done
# 823. elliott haut + done
# 824. anna hemnes + done
# 825. renee hsia + done
# 826. dineo khabele + done
# 827. scott kopetz + done
# 828. siavash kurdistani + done
# 829. samia mora + done
# 830. nima mosammaparast + done
# 831. nicolas musi + done
# 832. markus müschen + done
# 833. sattva neelapu + done
# 834. brian primack + done
# 835. jianwen que + done
# 836. manuela raffatellu + done
# 837. jordan shavit + done
# 838. aaron tobian + done
# 839. matthew vander heiden + done
# 840. arnold weissler + done
# 841. jonathan brestoff + done
# 842. gaurav gaiha + done
# 843. karuna ganesh + done
# 844. marie guerraty + done
# 845. michael kattah + done
# 846. robert samstein + done
# 847. santosha vardhana + done
# 848. andrew venteicher + done
# 849. themistocles assimes + done
# 850. julie bastarache + done
# 851. gregory bisson + done
# 852. katrin chua + done
# 853. stephanie eisenbarth + done
# 854. amit gaggar + done
# 855. santhi ganesh + done
# 856. johann gudjonsson + done
# 857. alan hanash + done
# 858. mark hatley + done
# 859. brent hollenbeck + done
# 860. erik ingelsson + done
# 861. shuta ishibe + done
# 862. fasiha kanwal + done
# 863. james kochenderfer + done
# 864. michail lionakis + done
# 865. meenakshi madhur + done
# 866. denise marciano + done
# 867. erica marsh + done
# 868. marcela maus + done
# 869. javid moslehi + done
# 870. lauren sansing + done
# 871. daichi shimbo + done
# 872. jennifer taylor-cousar + done
# 873. shreyas vasanawala + done
# 874. renda wiener + done
# 875. jennifer woyach + done
# 876. xilma ortiz-gonzalez + done
# 877. muktar aliyu + done
# 878. himisha beltran + done
# 879. supinda bunyavanich + done
# 880. mark burkard + done
# 881. nataki douglas + done
# 882. brian edelson + done
# 883. peter fecci + done
# 884. walid gellad + done
# 885. peyman golshani + done
# 886. petros karakousis + done
# 887. purna kashyap + done
# 888. anna köttgen + done
# 889. philana lin + done
# 890. piro lito + done
# 891. carey lumeng + done
# 892. tippi mackenzie + done
# 893. nuala meyer + done
# 894. erik musiek + done
# 895. peggy myung + done
# 896. utpal pajvani + done
# 897. chad pecot + done
# 898. jalees rehman + done
# 899. nasia safdar + done
# 900. joanna steinglass + done
# 901. nathan stitziel + done
# 902. hilary tindle + done
# 903. jinoos yazdany + done
# 904. julie zikherman + done
# 905. serine avagyan + done
# 906. jeeyeon cha + done
# 907. raghu chivukula + done
# 908. carlos diaz-balzac + done
# 909. neir eshel + done
# 910. celestine wanjalla + done
# 911. suneet agarwal + done
# 912. emmanuel antonarakis + done
# 913. valerie arboleda + done
# 914. ashwin balagopal + done
# 915. grant barish + done
# 916. ann chahroudi + done
# 917. william checkley + done
# 918. daniel chertow + done
# 919. julio chirinos + done
# 920. vineet chopra + done
# 921. hitesh deshmukh + done
# 922. tarek ashkar + done
# 923. areej el-jawahri + done
# 924. zachary freyberg + done
# 925. ankush gosain + done
# 926. ronna hertzano + done
# 927. lori jordan + done
# 928. kristopher kahle + done
# 929. rosandra kaplan + done
# 930. navin kapur + done
# 931. tim lahm + done
# 932. scott lorch + done
# 933. vincent marconi + done
# 934. emanual maverakis + done
# 935. saurabh mehandru + done
# 936. raina merchant + done
# 937. marcella nunez-smith + done
# 938. sara pai + done
# 939. matthew rondina + done
# 940. mara schonberg + done
# 941. julie schwarz + done
# 942. mark siedner + done
# 943. jason sperry + done
# 944. consuelo wilkins + done
# 945. rachel zemans + done
# 946. shan zha + done
# 947. william freed-pastor + done
# 948. alexander gitlin + done
# 949. gil hoftman + done
# 950. kartik pattabiraman + done
# 951. carolyn sangokoya + done
# 952. jay sarthy + done
# 953. josephine thinwa + done
# 954. maria  basil + done
# 955. glynnis garry + done
# 956. sattar khoshkhoo + done
# 957. paulo lizano + done
# 958. jacqueline parchem + done
# 959. sheila shanmugan + done
# 960. diana shi + done
# 961. joelle straehla + done
# 962. brian sweis + done
# 963. tobiloba oni + done
# 964. joelle  straehla + done
# 965. sean agbor-enoh + done
# 966. megan baldridge + done
# 967. evan brittain + done
# 968. eugenio cingolani + done
# 969. brian debosch + done
# 970. courtney dinardo + done
# 971. cynthia gyamfi-bannerman + done
# 972. lesley inker + done
# 973. yelena janjigian + done
# 974. christopher klebanoff + done
# 975. joanna klubo-gwiezdzinska + done
# 976. krista lentine + done
# 977. josh levitsky + done
# 978. harmeet malhi + done
# 979. sandeep mallipattu + done
# 980. supriya mohile + done
# 981. rahmi oklu + done
# 982. tiffany powell-wiley + done
# 983. stacey rentschler + done
# 984. katy rezvani + done
# 985. todd ridky + done
# 986. aylin rodan + done
# 987. marco ruella + done
# 988. cyndya shibao + done
# 989. barbara trautner + done
# 990. duane wesemann + done
# 991. amir zarrinpar + done
# 992. elad ziv + done
# 993. behdad afzali + done
# Failed queries: set()

# %%
with open("openAlex_ids.json", "w") as f:
    json.dump(ids_dictionary, f, indent=4)

# with open("openAlex_failed_queries.json", "w") as f:
#     json.dump(list(failed_queries), f, indent=4)

# %%
single_OP = []
with open("openAlex_ids.json", "r") as f:
    ids_dictionary = json.load(f)
for name in ids_dictionary.keys():
    if len(ids_dictionary[name]) == 1:
        single_OP.append(name)
print(single_OP)
print(len(single_OP))
# Out:
# ['yale nemerson', 'elia ayoub', 'john dietschy', 'yale enson', 'mehran goulian', 'hermes kontos', 'gilbert levinson', 'harvey marver', 'dorothea zucker-franklin', 'nathan zvaifler', 'phyllis bodel', 'sidney cooperband', 'jacques kessler', 'gildon beall', 'neil cherniack', 'shirley ebbe', 'clyde bardin', 'michael mosesson', 'leon sabath', 'jamshid javid', 'marshall lichtman', 'manning thaler', 'harry beaty', 'viktor bokisch', 'alexander fefer', 'darryl granner', 'sheldon rothenberg', 'edgar cathcart', 'franklyn knox', 'julian niemetz', 'antero so', 'leonard jarett', 'edwin beachey', 'guenther boden', 'vincent discala', 'laurence kedes', 'robert adelstein', 'joseph avruch', 'frederick derubertis', 'jack hawiger', 'ruy soeiro', 'bobby stinebaugh', 'kirk wuepper', 'philip coffino', 'daniel roncari', 'irwin scher', 'nicholas kredich', 'makio ogawa', 'matthew rechler', 'david rosenstreich', 'shigeru sassa', 'neil blacklow', 'philip guzelian', 'ione kourides', 'harry margolius', 'richard shadduck', 'william yarger', 'bertram felsher', 'marvin gershengorn', 'detlef schlondorff', 'manjeri venkatachalam', 'tomas berl', 'steven burakoff', 'ralph giannella', 'arnold postlethwaite', 'alex rabinovitch', 'arleen rifkind', 'carl apstein', 'meyer lifschitz', 'james niedel', 'john repine', 'sanford shattil', 'itamar abrass', 'robert bast jr.', 'barry festoff', 'charles homcy', 'mae hultin', 'bruce nisula', 'ivor royston', 'glen van loon', 'ronald whisler', 'douglas cines', 'theodore gabig', 'mercio perrin', 'jimmie sylvester', 'clifton bogardus', 'kiertisin dharmsathaphorn', 'boris draznin', 'leslie hillis', 'anne nicholson-weller', 'jess thoene', 'bennett blitzer', 'henry hulter', 'samuel santoro', 'greti aguilera', 'roger perlmutter', 'kenneth polonsky', 'howard welgus', 'christine abrass', 'loran clement', 'james gadek', 'jeffrey kudlow', 'henry masur', 'phillip pizzo', 'jonathan ashwell', 'clark distelhorst', 'subhash kukreja', 'cary mariash', 'robert meenan', 'gordon ginder', 'theodore krontiris', 'john lollar', 'mortimer poncz', 'petros tsipouras', 'janis abkowitz', 'allan detsky', 'francisco gonzalez-scarano', 'frederick gorelick', 'arthur gutierrez-hartmann', 'daniel rotrosen', 'gregory vercellotti', 'jeff sands', 'barbara ballermann', 'karol bomsztyk', 'richard granstein', 'charles natanson', 'michael selsted', 'webster cavenee', 'fabio cominelli', 'mary dinauer', 'howard lippton', 'sanford markowitz', 'william petri jr.', 'stephen wank', 'lee helman', 'gary koretzky', 'joan kreiss', 'cy stein', 'mary tinetti', 'douglas golenbock', 'razelle kurzrock', 'dwain thiele', 'hagop youssoufian', 'michael parmacek', 'richard kitsis', 'juanita merchant', 'ori rotstein', 'robert seder', 'howard worman', 'robert farese jr.', 'andrew karaplis', 'paul mccray jr.', 'linda demer', 'iswar hariharan', 'larry moreland', 'william skach', 'david nanus', 'ethel cesarman', 'stella kourembanas', 'orson moe', 'charles lowenstein', 'anne moscona', 'theodore standiford', 'luc teyton', 'preet chaudhary', 'phyllis dennery', 'glenn dranoff', 'theodora ross', 'barry sleckman', 'dwight towler', 'rexford ahima', 'alessandra pernis', 'ernestina schipani', 'joseph zabner', 'george cotsarelis', 'chaim putterman', 'robert heuckeroth', 'warren shlomchik', 'rulan parekh', 'jeanmarie houghton', 'samir khleif', 'keith march', 'vamsi mootha', 'stephanie seminara', 'john stamatoyannopoulos', 'omaida velazquez', 'feroz papa', 'nikolaos frangogiannis', 'mehrdad matloubian', 'franck mauvais-jarvis', 'kenneth ataga', 'terrence geiger', 'michael kapiloff', 'flora sam', 'eric sweet-cordero', 'john wemmie', 'james zimring', 'brian zuckerbraun', 'joel blankson', 'keith flaherty', 'jaime grutzendler', 'jonathan maltzman', 'kieren mather', 'irina petrache', 'lorraine ware', 'iris jaffe', 'wolfram goessling', 'farouc jaffer', 'ivan maillard', 'borna mehrad', 'yaël mossé', 'puneet opal', 'elizabeth speliotes', 'linda mcallister-lucas', 'theresa alenghat', 'christina barkauskas', 'jeffery k ...
# 330

# %%
Open_lower = [name.lower() for name in single_OP]
Dimens_lower = [name.lower() for name in names]

# Find the intersection of lowercase names
intersection_result = set(Open_lower).intersection(Dimens_lower)
intersection_list = list(intersection_result)

print(len(intersection_list))

#check
checker = False
for name in Open_lower:
    if name in Dimens_lower:
        checker = True
print(checker)
# Out:
# 330
# True

# %%
with open("combined_singleIds.txt", "w") as file:
    for name in intersection_list:
        file.write(name + '\n')
